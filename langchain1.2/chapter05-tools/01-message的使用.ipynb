# %%
# message的使用
from langchain_core.prompts import ChatPromptTemplate;
import os
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    model="MiniMax-M3",
    api_key='sk-cp-GsTRU_GlFRX_WPY8cf8IqBTDtrVJP4zl4EWLZ8D7627lrDtV-MbWYnWWK7rmvT7ZRluuMtUL7VP2sCD2uq6SzkpIlY0EAJtCIHW2uSGAT4QKYxX9mJQmK8I',
    base_url="https://api.minimaxi.com/v1",
)

chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "你是一个非常友好的AI助手，你的名字是{nameA}"),
    ("human", "你好，你最近怎么样？"),
    ("ai", "我很好，谢谢！你呢？"),
    ("human", "{user_input}"),
])
  
prompt_value = chat_prompt_template.invoke({"nameA": "小磊", "user_input": "你叫什么名字？2+2=?"})

response = model.invoke(prompt_value.messages)
print(response.content)
# Out:
# http://127.0.0.1:7890
# http://127.0.0.1:7890
# 你好！我是 MiniMax-M3。2+2=4。
