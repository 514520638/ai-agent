# %%
# 见  工具调用流程.png

from langchain_openai import ChatOpenAI
from dotenv import load_dotenv;
import os;
from rich import print as rprint
from langchain_core.utils.function_calling import convert_to_openai_tool

load_dotenv(override=True)  # 覆盖环境变量

model = ChatOpenAI(
    model="MiniMax-M3",
    api_key=os.getenv("api_key"),
    base_url=os.getenv("base_url"),
)
def get_weather(city: str= "北京") -> str:
    """
        模拟获取天气信息的函数 //description说明

        Args:
            city: str: 城市名称 //参数说明
            
        Returns:
            返回天气信息 //返回值说明,不现实
    """
    return f"{city}的天气是晴天，温度25摄氏度。"

model_with_tools = model.bind_tools([get_weather])  

# convert_to_oepnai_tool将传入函数转换成Tool实例
rprint(convert_to_openai_tool(get_weather))

response = model_with_tools.invoke("请告诉我北京的天气情况")
rprint(response)
# Out:
# {
#     'type': 'function',
#     'function': {
#         'name': 'get_weather',
#         'description': '模拟获取天气信息的函数 //description说明',
#         'parameters': {
#             'properties': {
#                 'city': {'default': '北京', 'description': 'str: 城市名称 //参数说明', 'type': 'string'}
#             },
#             'type': 'object'
#         }
#     }
# }
# AIMessage(
#     content='<think>用户询问北京的天气情况。我需要使用 get_weather
# 函数来获取北京的天气信息。函数的默认城市就是北京,但我可以明确指定城市参数为"北京"以确保准确。</think>\n\n我来帮您查
# 询北京的天气情况。',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 75,
#             'prompt_tokens': 423,
#             'total_tokens': 498,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 37,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 384},
#             'total_characters': 0
#         },
#         'model_provider': 'openai',
#         'model_name': 'MiniMax-M3',
#         'system_fingerprint': None,
#         'id': '06c8762b54b2ac60c043137fefb9b8b5',
#         'service_tier': 'standard',
#         'finish_reason': 'tool_calls',
#         'logprobs': None
#     },
#     id='lc_run--019fe9ae-5a73-7453-b8c4-070dac8ecd0e-0',
#     tool_calls=[
#         {
#             'name': 'get_weather',
#             'args': {'city': '北京'},
#             'id': 'call_019fe9ae6d497680a4593c6b',
#             'type': 'tool_call'
#         }
#     ],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 423,
#         'output_tokens': 75,
#         'total_tokens': 498,
#         'input_token_details': {'cache_read': 384},
#         'output_token_details': {'reasoning': 37}
#     }
# )
