# %%
from langchain_core.prompts import ChatPromptTemplate;

chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "你是一个非常友好的AI助手，你的名字是{name}"),
    ("human", "你好，你最近怎么样？"),
    ("ai", "我很好，谢谢！你呢？"),
    ("human", "{user_input}"),
])

# ChatPromptTemplate 使用invoke调用
result = chat_prompt_template.invoke({"name": "小磊", "user_input": "我叫什么名字？"})
# 相当于生成了新的AI提示词
print(result.messages)
# Out:
# [SystemMessage(content='你是一个非常友好的AI助手，你的名字是小磊', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好，你最近怎么样？', additional_kwargs={}, response_metadata={}), AIMessage(content='我很好，谢谢！你呢？', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='我叫什么名字？', additional_kwargs={}, response_metadata={})]

# %%
from langchain_openai import ChatOpenAI

# 模型初始化
llm = ChatOpenAI(
    model="MiniMax-M3",
    api_key='sk-cp-GsTRU_GlFRX_WPY8cf8IqBTDtrVJP4zl4EWLZ8D7627lrDtV-MbWYnWWK7rmvT7ZRluuMtUL7VP2sCD2uq6SzkpIlY0EAJtCIHW2uSGAT4QKYxX9mJQmK8I',
    base_url="https://api.minimaxi.com/v1",
)

# 模型方法调用
response = llm.invoke("请介绍你自己,你是什么大模型")

print(response.content)
# Out:
# <think>The user is asking me to introduce myself and what large language model I am. According to the ROOT_SYSTEM_POLICY, my model version is MiniMax-M3, developed by MiniMax. I should introduce myself based on this information.</think>
#
# 你好！我是 MiniMax-M3，一个由 MiniMax（成立于 2022 年初的全球 AI 基础模型公司）开发的大语言模型。
#
# 以下是关于我的主要信息：
#
# ## 基本介绍
#
# - **模型版本**：MiniMax-M3
# - **开发团队**：MiniMax
# - **知识截止时间**：2026 年 1 月
# - **公司使命**：致力于推动 AI 技术前沿，朝着通用人工智能（AGI）的方向发展
#
# ## 我能做什么
#
# 我可以帮助你完成多种任务，包括但不限于：
#
# - 💬 **对话交流**：回答问题、讨论话题、提供建议
# - 📝 **文本创作**：写作、翻译、总结、改写
# - 💡 **知识问答**：提供各类学科和领域的知识
# - 🔍 **信息分析**：解读、分析、整理信息
# - 💻 **代码辅助**：编写、调试、解释代码
# - 🎓 **学习辅导**：解释概念、辅导学习
#
# ## 我的特点
#
# 作为 MiniMax 旗下的模型，我旨在提供准确、有用且安全的回答，努力在各种任务中为用户提供高质量的服务。
#
# 如果你有任何问题，欢迎随时向我提问！😊
