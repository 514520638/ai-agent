# %%
# 流式调用(stream)

from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="MiniMax-M3",
    api_key='sk-cp-GsTRU_GlFRX_WPY8cf8IqBTDtrVJP4zl4EWLZ8D7627lrDtV-MbWYnWWK7rmvT7ZRluuMtUL7VP2sCD2uq6SzkpIlY0EAJtCIHW2uSGAT4QKYxX9mJQmK8I',
    base_url="https://api.minimaxi.com/v1",
)

response =llm.stream("解释一下什么是ai")
for chunk in response:
    print(chunk.text, end="", flush=True)
# Out:
# <think>The user is asking me to explain what AI is in Chinese. I'll provide a comprehensive explanation covering the definition, history, types, applications, and future prospects of AI.</think>
#
# # 什么是人工智能（AI）？
#
# 人工智能（Artificial Intelligence，简称 **AI**）是一门研究如何让计算机系统具有类似人类智能能力的科学与工程学科。它的核心目标是让机器能够**感知、推理、学习、决策和创造**，从而胜任通常需要人类智慧才能完成的任务。
#
# ---
#
# ## 一、AI 的基本定义
#
# AI 试图让机器模拟人类的认知能力，主要包括：
#
# | 能力 | 说明 | 举例 |
# |------|------|------|
# | **感知** | 识别图像、声音、文本等 | 人脸识别、语音助手 |
# | **推理** | 基于逻辑做出判断 | 象棋博弈、专家诊断 |
# | **学习** | 从数据中提取规律 | 推荐系统、自动驾驶 |
# | **决策** | 在多种方案中选择最优 | 路径规划、投资策略 |
# | **创造** | 生成新的内容 | AI 绘画、文章写作 |
#
# ---
#
# ## 二、AI 的发展阶段
#
# 1. **弱人工智能（Narrow AI）**：专注于特定任务，例如语音识别、图像分类。目前我们使用的 AI 大多属于这一类。
#
# 2. **强人工智能（General AI）**：具备与人类相当的通用智能，能在任何智力任务上达到人类水平。这是 AI 研究的长远目标，**尚未实现**。
#
# 3. **超级人工智能（Super AI）**：超越人类智能水平的 AI，目前只存在于理论探讨中。
#
# ---
#
# ## 三、AI 的核心技术
#
# - **机器学习（ML）**：让计算机从数据中学习规律，而无需显式编程。
# - **深度学习（DL）**：使用多层神经网络处理复杂任务，如图像与语音。
# - **自然语言处理（NLP）**：让机器理解和生成人类语言。
# - **计算机视觉**：让机器"看懂"图像和视频。
# - **强化学习**：通过试错与环境交互学习最优策略。
#
# ---
#
# ## 四、AI 的常见应用
#
# - 🏥 **医疗**：辅助诊断、药物研发
# - 🚗 **交通**：自动驾驶、智能交通管理
# - 💬 **生活**：聊天机器人、智能音箱、翻译
# - 🏭 **工业**：智能制造、质量检测
# - 🎨 **艺术**：AI 绘画、音乐创作
# - 💰 **金融**：风控、量化交易
#
# ---
#
# ## 五、AI 的优势与挑战
#
# **优势：**
# - 高效率、低错误率
# - 可以 24 小时不间断工作
# - 处理海量数据能力强
#
# **挑战：**
# - **伦理问题**：隐私、偏见、责任归属
# - **就业冲击**：部分职业可能被替代
# - **安全风险**：深度伪造、算法滥用
# - **技术门槛**：研发成本高，数据依赖性强
#
# ---
#
# ## 总结
#
# AI 是当今最具变革性的技术之一，正在深刻改变我们的生活、工作和社会形态。它既是推动人类进步的强大工具，也需要我们谨慎对待其带来的伦理与社会问题。理解 AI，才能更好地与它共存并驾驭它。
#
# 如果你想了解某个具体方面（如机器学习原理、AI 在某行业的应用等），我可以继续深入讲解 😊
