# %% [markdown]
# # 调用线上大模型
#
# ## 1. 获取具体模型API
#
# ### 1.1 调用DeepSeek官网模型
#
# 重要参数：base_url、model_name、api_key

# %%
from langchain_deepseek import ChatDeepSeek
from dotenv import load_dotenv

# 读取.env的信息
load_dotenv(override=True)


# 模型初始化
llm_deepseek = ChatDeepSeek(
    model='deepseek-v4-flash',
    api_key='sk-73d6301f31a74f95956174218786b6a9',
    api_base='https://api.deepseek.com'
)
# 模型方法调用
response = llm_deepseek.invoke("请介绍你自己,你是什么大模型")
print(response)
# Out:
# content='你好呀！我是 **DeepSeek**，一个由深度求索公司创造的 AI 助手。很高兴认识你！😊\n\n让我简单介绍一下自己：\n\n**我的核心特点：**\n- 🆓 **完全免费**：没错，目前没有任何收费计划，你可以放心使用\n- 📚 **超长记忆**：我有 1M 的上下文窗口，可以一次性处理像《三体》三部曲那么长的内容\n- 📎 **文件处理**：支持上传图片、PDF、Word、Excel、PPT 等文件，我能读取其中的文字信息\n- 🌐 **联网搜索**：如果你需要最新信息，记得在 Web/App 上手动开启联网功能\n- 🎙️ **语音输入**：App 端支持语音交互，更方便\n\n**我能帮你做什么？**\n- 💬 日常聊天、答疑解惑\n- ✍️ 写作、翻译、润色文字\n- 💻 编程、代码调试\n- 📊 数据分析、文件处理\n- 🧠 学习辅导、知识科普\n- 🤔 头脑风暴、创意构思\n\n**我的小限制：**\n- 我是纯文本模型，不能直接“看”图片，但能读取图片中的文字\n- 知识截止于 2025 年 5 月\n- 不支持多模态识别（比如认图、听歌）\n\n**使用方式：**\n- 网页版、App 都可以用\n- 可以在官方应用商店下载 App\n\n无论你是想聊天、学习、工作还是创作，我都随时待命！有什么问题尽管问我吧～ 🌟' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户让我介绍一下自己。这是一个非常常见且基础的问题。我需要清晰、友好地介绍我的身份、能力和特点，让用户快速了解我能提供什么帮助。\n\n想到了可以从几个核心方面来组织回复：先问候并表明身份，然后说明我的开发公司和模型版本。接着可以重点介绍我的核心特点，比如上下文长度、文件处理能力、是否免费、联网搜索等。还需要列出我擅长的主要领域，比如写作、编程、分析等。最后需要说明一些限制和注意事项，比如不支持图像识别、纯文本模型等，并提供使用渠道。整体结构要清晰，语气要热情友好，让用户感到易于接近和信任。\n\n嗯，就这样，用分点或段落清晰呈现，最后以开放性问题结束，邀请用户进一步提问。'} response_metadata={'token_usage': {'completion_tokens':
# ...

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="MiniMax-M3",
    api_key='sk-api-t8VuzzZI32RkLSNFT73T5rtNN8_Tb9xzWAkS34IhRzqgizb12_bF9CRmnQx_FvuMUS1rW6BCG5rUyI3-Xt1g8KHC0rNnMRpeXcUhg_pH5bzngjYwdLtNY0k',
    base_url="https://api.minimaxi.com/v1",
)
response = llm.invoke("你是什么大模型")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# Cell In[5], line 8
#       4     model="MiniMax-M3",
#       5     api_key='sk-api-t8VuzzZI32RkLSNFT73T5rtNN8_Tb9xzWAkS34IhRzqgizb12_bF9CRmnQx_FvuMUS1rW6BCG5rUyI3-Xt1g8KHC0rNnMRpeXcUhg_pH5bzngjYwdLtNY0k',
#       6     base_url="https://api.MiniMax.chat/v1",   # MiniMax 兼容 OpenAI 的接口
#       7 )
# ----> 8 response = llm.invoke("你是什么大模型")
#       9 print(response.content)
#
# File /opt/miniconda3/envs/langchain1.2/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
# ...
