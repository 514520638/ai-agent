# %%
# 通用的模型调用
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="MiniMax-M3",
    api_key='sk-cp-GsTRU_GlFRX_WPY8cf8IqBTDtrVJP4zl4EWLZ8D7627lrDtV-MbWYnWWK7rmvT7ZRluuMtUL7VP2sCD2uq6SzkpIlY0EAJtCIHW2uSGAT4QKYxX9mJQmK8I',
    base_url="https://api.minimaxi.com/v1",
    temperature=1.9,
    max_tokens=1024,
)
response = llm.invoke("评价一下宏星模型1:43的rc遥控车怎么样")
print(response.content)
# Out:
# <think>用户询问的是宏星模型（Macro Star Models）1:43比例的RC遥控车的评价。我需要基于我所了解的信息来回答。让我想想这个品牌和产品线。
#
# 宏星模型（Macro Star Models）是一家中国模型公司，主要生产各种比例的遥控车模型。1:43比例是比较小的比例，主要面向桌面级收藏和轻度把玩市场。
#
# 让我分析一下这类产品的特点：
#
# 1. 品牌背景：宏星模型在国内遥控车模型圈有一定知名度，产品线涵盖多个比例
# 2. 1:43比例特点：体积小巧，适合室内把玩，价格相对较低
# 3. 技术规格：通常采用较简单的电子设备，适合入门用户
# 4. 做工质量：在同价位产品中表现尚可，但与高端品牌（如京商、Kyosho等）有明显差距
#
# 我需要客观地评价这款产品，既要指出优点，也要说明不足。</think>
#
# # 宏星模型 1:43 RC遥控车评价
#
# ## 品牌背景
# 宏星模型（Macro Star Models）是中国知名的遥控车模型厂商之一，产品线覆盖1:10、1:14、1:16、1:18、1:24、1:43等多个比例，在国内外遥控车爱好者中有一定的市场份额。
#
# ## 1:43比例车型的特点
#
# ### ✅ 优点
# - **体积小巧**：1:43比例车身小巧，适合桌面摆放和室内把玩，不占空间
# - **价格亲民**：相比1:10、1:14等大比例车型，售价较低（通常几百到一千多元），入门门槛低
# - **题材丰富**：宏星在1:43比例上有较丰富的车型选择，如保时捷、奔驰、丰田等经典车型
# - **仿真度高**：外观还原度不错，油漆和细节做工在同价位中表现尚可
# - **携带方便**：体积小，便于外出携带，可以在办公室、家里随时把玩
#
# ### ⚠️ 不足之处
# - **性能有限**：1:43比例车体较小，难以容纳高性能电机和电调，速度和越野性能有限
# - **电子设备较基础**：通常采用较为简单的遥控系统和动力配置，操控手感一般
# - **电池续航**：小体积限制电池容量，玩耍时间相对较短
# - **配件与升级空间小**：相比1:10等大比例车型，可玩性和升级空间有限
# - **做工细节**：与日本Kyosho、京商、PN Racing等品牌相比，做工和材质仍有差距
#
# ## 适用人群
# - 🔰 **入门玩家**：想体验RC遥控车但预算有限的新手
# - 🪑 **桌面党**：喜欢摆放在桌面或展柜里欣赏的车模爱好者
# - 🎁 **礼品用途**：作为礼物送给孩子或车模爱好者
# - 🏎️ **多车收藏**：想以较低成本收集多种车型的玩家
#
# ## 综合评价
# **性价比评分：7/10**
#
# 宏星1:43 RC遥控车在同价位产品中表现合格，是一款**入门级的把玩型车模**。如果你追求的是**真车比例外观+轻度遥控乐趣**，这款车是不错的选择。但如果你想要**高性能越野体验**或**专业竞速操控**，建议考虑1:14或1:10比例的车型。
#
# ## 💡 购买建议
# 1. 明确需求：是收藏展示还是实际把玩？
# 2. 关注具体型号的评测视频
# 3. 建议在官方渠道或正规经销商处购买，售后有保障
# 4. 可以先入手一台体验，再决定是否升级到更大比例
#
# 需要我帮你对比某款具体型号，或者推荐其他类似产品吗？
